# %% [markdown]
# # Sand - Melio POC

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime

techFile = '../../data/domain-technologies.csv'
spendFile = '../../data/domain-spend.csv'

tech_data = pd.read_csv(techFile)
spend_data = pd.read_csv(spendFile)

# %% [markdown]
# ## Utilities

# %% [markdown]
# ### Normalizaiton Utilities

# %%
import datetime
from dateutil.relativedelta import relativedelta

def ticks_to_datetime(ticks):
    #print('ticks_to_datetime: ', ticks)
    if pd.isna(ticks):
        return math.nan
    
    pyticks = ticks
    if len(str(ticks)) > 10: # JSON time ticks
        pyticks = int(ticks / 1000);
    
    return datetime.datetime.fromtimestamp(pyticks)


def add_months_to_datetime(dt, count):
    return dt + relativedelta(months=count)

# %% [markdown]
# ### Slicing Utilities

# %%
#def total_technologies_per_domain(df, excludeTags):
#    return df.loc(df['Zipcode'] == zipcode & df['Sold year'] == sold_year)

def tech_for_domain(df, domain):
    return df.loc[df['Domain'] == domain]
    
def count_tech_per_domain(df, excludeTags):
    return df.groupby(['Domain']).size()

def count_tech_per_domain_and_subdomain(df, excludeTags):
    return df.groupby(['Domain','SubDomain']).size()

def spend_for_domain(df, domain):
    return df.loc[df['LookupDomain'] == domain]

# %% [markdown]
# ### Plot Utilities

# %%
def view_table(df, count):
    return df.head(count).style.set_properties(**{'background-color': 'Light Grey', 'color': 'Black', 'border-color': 'white'})

def plot_count_over_time(df, title, timeCol, countCol, countLabel):
    data = {
        timeCol: df[timeCol].values,
        countCol: df[countCol].values
    }
        
    df = pd.DataFrame(data)
    #df['SpendDate'] = pd.to_datetime(df['SpendDate'])

    # Set SpendDate as the DataFrame index
    df.set_index(timeCol, inplace=True)

    # Generate a sequence of dates from the minimum to the maximum date in the DataFrame
    date_range = pd.date_range(df.index.min(), df.index.max(), freq='MS')

    # Reindex the DataFrame with the generated date range, filling missing values with the previous available value
    df = df.reindex(date_range, method='ffill')

    # Plot the SpendSum over time using a line plot
    df.plot(marker='.', linestyle='-', linewidth=2, markersize=6)

    # Customize the plot
    plt.xlabel('Time')
    plt.ylabel(countLabel)
    plt.title(title)

    # Show the plot
    plt.show()

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Overview

# %%
view_table(tech_data,5)
# Out:
# <style type="text/css">
# #T_74409_row0_col0, #T_74409_row0_col1, #T_74409_row0_col2, #T_74409_row0_col3, #T_74409_row0_col4, #T_74409_row0_col5, #T_74409_row0_col6, #T_74409_row0_col7, #T_74409_row0_col8, #T_74409_row0_col9, #T_74409_row0_col10, #T_74409_row0_col11, #T_74409_row0_col12, #T_74409_row0_col13, #T_74409_row0_col14, #T_74409_row0_col15, #T_74409_row0_col16, #T_74409_row0_col17, #T_74409_row0_col18, #T_74409_row0_col19, #T_74409_row0_col20, #T_74409_row0_col21, #T_74409_row0_col22, #T_74409_row0_col23, #T_74409_row0_col24, #T_74409_row0_col25, #T_74409_row0_col26, #T_74409_row0_col27, #T_74409_row0_col28, #T_74409_row1_col0, #T_74409_row1_col1, #T_74409_row1_col2, #T_74409_row1_col3, #T_74409_row1_col4, #T_74409_row1_col5, #T_74409_row1_col6, #T_74409_row1_col7, #T_74409_row1_col8, #T_74409_row1_col9, #T_74409_row1_col10, #T_74409_row1_col11, #T_74409_row1_col12, #T_74409_row1_col13, #T_74409_row1_col14, #T_74409_row1_col15, #T_74409_row1_col16, #T_74409_row1_col17, #T_74409_row1_col18, #T_74409_row1_col19, #T_74409_row1_col20, #T_74409_row1_col21, #T_74409_row1_col22, #T_74409_row1_col23, #T_74409_row1_col24, #T_74409_row1_col25, #T_74409_row1_col26, #T_74409_row1_col27, #T_74409_row1_col28, #T_74409_row2_col0, #T_74409_row2_col1, #T_74409_row2_col2, #T_74409_row2_col3, #T_74409_row2_col4, #T_74409_row2_col5, #T_74409_row2_col6, #T_74409_row2_col7, #T_74409_row2_col8, #T_74409_row2_col9, #T_74409_row2_col10, #T_74409_row2_col11, #T_74409_row2_col12, #T_74409_row2_col13, #T_74409_row2_col14, #T_74409_row2_col15, #T_74409_row2_col16, #T_74409_row2_col17, #T_74409_row2_col18, #T_74409_row2_col19, #T_74409_row2_col20, #T_74409_row2_col21, #T_74409_row2_col22, #T_74409_row2_col23, #T_74409_row2_col24, #T_74409_row2_col25, #T_74409_row2_col26, #T_74409_row2_col27, #T_74409_row2_col28, #T_74409_row3_col0, #T_74409_row3_col1, #T_74409_row3_col2, #T_74409_row3_col3, #T_74409_row3_col4, #T_74409_row3_col5, #T_74409_row3_col6, #T_74409_row3_col7, #T_74409_row3_col8, #T_74409_row3_col9, #T_74409_row3_col10, #T_74409_row3_col11, #T_74409_row3_col12, #T_74409_row3_col13, #T_74409_row3_col14, #T_74409_row3_col15, #T_74409_row3_col16, #T_74409_row3_col17, #T_74409_row3_col18, #T_74409_row3_col19, #T_74409_row3_col20, #T_74409_row3_col21, #T_74409_row3_col22, #T_74409_row3_col23, #T_74409_row3_col24, #T_74409_row3_col25, #T_74409_row3_col26, #T_74409_row3_col27, #T_74409_row3_col28, #T_74409_row4_col0, #T_74409_row4_col1, #T_74409_row4_col2, #T_74409_row4_col3, #T_74409_row4_col4, #T_74409_row4_col5, #T_74409_row4_col6, #T_74409_row4_col7, #T_74409_row4_col8, #T_74409_row4_col9, #T_74409_row4_col10, #T_74409_row4_col11, #T_74409_row4_col12, #T_74409_row4_col13, #T_74409_row4_col14, #T_74409_row4_col15, #T_74409_row4_col16, #T_74409_row4_col17, #T_74409_row4_col18, #T_74409_row4_col19, #T_74409_row4_col20, #T_74409_row4_col21, #T_74409_row4_col22, #T_74409_row4_col23, #T_74409_row4_col24, #T_74409_row4_col25, #T_74409_row4_col26, #T_74409_row4_col27, #T_74409_row4_col28 {
#   background-color: Light Grey;
#   color: Black;
#   border-color: white;
# }
# </style>
# <table id="T_74409">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74409_level0_col0" class="col_heading level0 col0" >Domain</th>
#       <th id="T_74409_level0_col1" class="col_heading level0 col1" >SubDomain</th>
#       <th id="T_74409_level0_col2" class="col_heading level0 col2" >Url</th>
#       <th id="T_74409_level0_col3" class="col_heading level0 col3" >FirstIndexed</th>
#       <th id="T_74409_level0_col4" class="col_heading level0 col4" >LastIndexed</th>
#       <th id="T_74409_level0_col5" class="col_heading level0 col5" >CompanyName</th>
#       <th id="T_74409_level0_col6" class="col_heading level0 col6" >Vertical</th>
#       <th id="T_74409_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_74409_level0_col8" class="col_heading level0 col8" >Country</th>
#       <th id="T_74409_level0_col9" class="col_heading level0 col9" >ARank</th>
#       <th id="T_74409_level0_col10" class="col_heading level0 col10" >QRank</th>
#       <th id="T_74409_level0_col11" class="col_heading level0 col11" >Name</th>
#       <th id="T_74409_level0_col12" class="col_heading level0 col12" >Parent</th>
#       <th id="T_74409_level0_col13" class="col_heading level0 col13" >FirstDetected</th>
#       <th id="T_74409_level0_col14" class="col_heading level0 col14" >LastDetected</th>
#       <th id="T_74409_level0_col15" class="col_heading level0 col15" >IsLive</th>
#       <th id="T_74409_level0_col16" class="col_heading level0 col16" >IsPremium</th>
#       <th id="T_74409_level0_col17" class="col_heading level0 col17" >Link</th>
#       <th id="T_74409_level0_col18" class="col_heading level0 col18" >Tag</th>
#       <th id="T_74409_level0_col19" class="col_heading level0 col19" >Category0</th>
#       <th id="T_74409_level0_col20" class="col_heading level0 col20" >Category1</th>
#       <th id="T_74409_level0_col21" class="col_heading level0 col21" >Category2</th>
#       <th id="T_74409_level0_col22" class="col_heading level0 col22" >Category3</th>
#       <th id="T_74409_level0_col23" class="col_heading level0 col23" >Category4</th>
#       <th id="T_74409_level0_col24" class="col_heading level0 col24" >Category5</th>
#       <th id="T_74409_level0_col25" class="col_heading level0 col25" >Category6</th>
#       <th id="T_74409_level0_col26" class="col_heading level0 col26" >Category7</th>
#       <th id="T_74409_level0_col27" class="col_heading level0 col27" >Category8</th>
#       <th id="T_74409_level0_col28" class="col_heading level0 col28" >Category9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74409_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74409_row0_col0" class="data row0 col0" >car4vip.com.pl</td>
#       <td id="T_74409_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_74409_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_74409_row0_col3" class="data row0 col3" >1566774000000</td>
#       <td id="T_74409_row0_col4" class="data row0 col4" >1688454000000</td>
#       <td id="T_74409_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_74409_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_74409_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_74409_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_74409_row0_col9" class="data row0 col9" >82279258</td>
#       <td id="T_74409_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_74409_row0_col11" class="data row0 col11" >Home PL</td>
#       <td id="T_74409_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_74409_row0_col13" class="data row0 col13" >1566774000000</td>
#       <td id="T_74409_row0_col14" class="data row0 col14" >1688454000000</td>
#       <td id="T_74409_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_74409_row0_col16" class="data row0 col16" >no</td>
#       <td id="T_74409_row0_col17" class="data row0 col17" >https://home.pl</td>
#       <td id="T_74409_row0_col18" class="data row0 col18" >hosting</td>
#       <td id="T_74409_row0_col19" class="data row0 col19" >Polish hosting</td>
#       <td id="T_74409_row0_col20" class="data row0 col20" >nan</td>
#       <td id="T_74409_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_74409_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_74409_row0_col23" class="data row0 col23" >nan</td>
#       <td id="T_74409_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_74409_row0_col25" class="data row0 col25" >nan</td>
#       <td id="T_74409_row0_col26" class="data row0 col26" >nan</td>
#       <td id="T_74409_row0_col27" class="data row0 col27" >nan</td>
#       <td id="T_74409_row0_col28" class="data row0 col28" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_74409_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74409_row1_col0" class="data row1 col0" >car4vip.com.pl</td>
#       <td id="T_74409_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T

# %%
# tech_data.describe()

# %%
view_table(spend_data,5)
# Out:
# <style type="text/css">
# #T_98c18_row0_col0, #T_98c18_row0_col1, #T_98c18_row0_col2, #T_98c18_row0_col3, #T_98c18_row0_col4, #T_98c18_row0_col5, #T_98c18_row0_col6, #T_98c18_row0_col7, #T_98c18_row0_col8, #T_98c18_row0_col9, #T_98c18_row0_col10, #T_98c18_row0_col11, #T_98c18_row1_col0, #T_98c18_row1_col1, #T_98c18_row1_col2, #T_98c18_row1_col3, #T_98c18_row1_col4, #T_98c18_row1_col5, #T_98c18_row1_col6, #T_98c18_row1_col7, #T_98c18_row1_col8, #T_98c18_row1_col9, #T_98c18_row1_col10, #T_98c18_row1_col11, #T_98c18_row2_col0, #T_98c18_row2_col1, #T_98c18_row2_col2, #T_98c18_row2_col3, #T_98c18_row2_col4, #T_98c18_row2_col5, #T_98c18_row2_col6, #T_98c18_row2_col7, #T_98c18_row2_col8, #T_98c18_row2_col9, #T_98c18_row2_col10, #T_98c18_row2_col11, #T_98c18_row3_col0, #T_98c18_row3_col1, #T_98c18_row3_col2, #T_98c18_row3_col3, #T_98c18_row3_col4, #T_98c18_row3_col5, #T_98c18_row3_col6, #T_98c18_row3_col7, #T_98c18_row3_col8, #T_98c18_row3_col9, #T_98c18_row3_col10, #T_98c18_row3_col11, #T_98c18_row4_col0, #T_98c18_row4_col1, #T_98c18_row4_col2, #T_98c18_row4_col3, #T_98c18_row4_col4, #T_98c18_row4_col5, #T_98c18_row4_col6, #T_98c18_row4_col7, #T_98c18_row4_col8, #T_98c18_row4_col9, #T_98c18_row4_col10, #T_98c18_row4_col11 {
#   background-color: Light Grey;
#   color: Black;
#   border-color: white;
# }
# </style>
# <table id="T_98c18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98c18_level0_col0" class="col_heading level0 col0" >LookupDomain</th>
#       <th id="T_98c18_level0_col1" class="col_heading level0 col1" >FirstIndexed</th>
#       <th id="T_98c18_level0_col2" class="col_heading level0 col2" >LastIndexed</th>
#       <th id="T_98c18_level0_col3" class="col_heading level0 col3" >SalesRevenue</th>
#       <th id="T_98c18_level0_col4" class="col_heading level0 col4" >SpendDate</th>
#       <th id="T_98c18_level0_col5" class="col_heading level0 col5" >SpendSum</th>
#       <th id="T_98c18_level0_col6" class="col_heading level0 col6" >CompanyName</th>
#       <th id="T_98c18_level0_col7" class="col_heading level0 col7" >Vertical</th>
#       <th id="T_98c18_level0_col8" class="col_heading level0 col8" >State</th>
#       <th id="T_98c18_level0_col9" class="col_heading level0 col9" >Country</th>
#       <th id="T_98c18_level0_col10" class="col_heading level0 col10" >ARank</th>
#       <th id="T_98c18_level0_col11" class="col_heading level0 col11" >QRank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98c18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98c18_row0_col0" class="data row0 col0" >businesslease.pl</td>
#       <td id="T_98c18_row0_col1" class="data row0 col1" >1013155200000</td>
#       <td id="T_98c18_row0_col2" class="data row0 col2" >1689404400000</td>
#       <td id="T_98c18_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_98c18_row0_col4" class="data row0 col4" >1024426020000</td>
#       <td id="T_98c18_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_98c18_row0_col6" class="data row0 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_98c18_row0_col7" class="data row0 col7" >Business And Industrial</td>
#       <td id="T_98c18_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_98c18_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_98c18_row0_col10" class="data row0 col10" >15805159</td>
#       <td id="T_98c18_row0_col11" class="data row0 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98c18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98c18_row1_col0" class="data row1 col0" >businesslease.pl</td>
#       <td id="T_98c18_row1_col1" class="data row1 col1" >1013155200000</td>
#       <td id="T_98c18_row1_col2" class="data row1 col2" >1689404400000</td>
#       <td id="T_98c18_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_98c18_row1_col4" class="data row1 col4" >1532458020000</td>
#       <td id="T_98c18_row1_col5" class="data row1 col5" >40</td>
#       <td id="T_98c18_row1_col6" class="data row1 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_98c18_row1_col7" class="data row1 col7" >Business And Industrial</td>
#       <td id="T_98c18_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_98c18_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_98c18_row1_col10" class="data row1 col10" >15805159</td>
#       <td id="T_98c18_row1_col11" class="data row1 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98c18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98c18_row2_col0" class="data row2 col0" >businesslease.pl</td>
#       <td id="T_98c18_row2_col1" class="data row2 col1" >1013155200000</td>
#       <td id="T_98c18_row2_col2" class="data row2 col2" >1689404400000</td>
#       <td id="T_98c18_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_98c18_row2_col4" class="data row2 col4" >1589482020000</td>
#       <td id="T_98c18_row2_col5" class="data row2 col5" >507</td>
#       <td id="T_98c18_row2_col6" class="data row2 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_98c18_row2_col7" class="data row2 col7" >Business And Industrial</td>
#       <td id="T_98c18_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_98c18_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_98c18_row2_col10" class="data row2 col10" >15805159</td>
#       <td id="T_98c18_row2_col11" class="data row2 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98c18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98c18_row3_col0" class="data row3 col0" >businesslease.pl</td>
#       <td id="T_98c18_row3_col1" class="data row3 col1" >1013155200000</td>
#       <td id="T_98c18_row3_col2" class="data row3 col2" >1689404400000</td>
#       <td id="T_98c18_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_98c18_row3_col4" class="data row3 col4" >1687978020000</td>
#       <td id="T_98c18_row3_col5" class="data row3 col5" >498</td>
#       <td id="T_98c18_row3_col6" class="data row3 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_98c18_row3_col7" class="data row3 col7" >Business And Industrial</td>
#       <td id="T_98c18_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_98c18_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_98c18_row3_col10" class="data row3 col10" >15805159</td>
#       <td id="T_98c18_row3_col11" class="data row3 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98c18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98c18_row4_col0" class="data row4 col0" >businesslease.pl</td>
#       <td id="T_98c18_row4_col1" class="data row4 col1" >1013155200000</td>
#       <td id="T_98c18_row4_col2" class="data row4 col2" >1689404400000</td>
#       <td id="T_98c18_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_98c18_row4_col4" class="data row4 col4" >1689404400000</td>
#       <td id="T_98c18_row4_col5" class="data row4 col5" >507</td>
#       <td id="T_98c18_row4_col6" class="data row4 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_98c18_row4_col7" class="data row4 col7" >Business And Industrial</td>
#       <td id="T_98c18_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_98c18_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_98c18_row4_col10" class="data row4 col10" >15805159</td>
#       <td id="T_98c18_row4_col11" class="data row4 col11" >-1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# spend_data.describe()

# %% [markdown]
# ### Normalization

# %%
### Normalize tech_data

# Convert json ticks to datetime
tech_data['FirstIndexed'] = tech_data['FirstIndexed'].apply(ticks_to_datetime)
tech_data['LastIndexed'] = tech_data['LastIndexed'].apply(ticks_to_datetime)
tech_data['FirstDetected'] = tech_data['FirstDetected'].apply(ticks_to_datetime)
tech_data['LastDetected'] = tech_data['LastDetected'].apply(ticks_to_datetime)


### Normalize spend_data

# Convert json ticks to datetime
spend_data['FirstIndexed'] = spend_data['FirstIndexed'].apply(ticks_to_datetime)
spend_data['LastIndexed'] = spend_data['LastIndexed'].apply(ticks_to_datetime)
spend_data['SpendDate'] = spend_data['SpendDate'].apply(ticks_to_datetime)

view_table(spend_data,3)
# Out:
# <style type="text/css">
# #T_40474_row0_col0, #T_40474_row0_col1, #T_40474_row0_col2, #T_40474_row0_col3, #T_40474_row0_col4, #T_40474_row0_col5, #T_40474_row0_col6, #T_40474_row0_col7, #T_40474_row0_col8, #T_40474_row0_col9, #T_40474_row0_col10, #T_40474_row0_col11, #T_40474_row1_col0, #T_40474_row1_col1, #T_40474_row1_col2, #T_40474_row1_col3, #T_40474_row1_col4, #T_40474_row1_col5, #T_40474_row1_col6, #T_40474_row1_col7, #T_40474_row1_col8, #T_40474_row1_col9, #T_40474_row1_col10, #T_40474_row1_col11, #T_40474_row2_col0, #T_40474_row2_col1, #T_40474_row2_col2, #T_40474_row2_col3, #T_40474_row2_col4, #T_40474_row2_col5, #T_40474_row2_col6, #T_40474_row2_col7, #T_40474_row2_col8, #T_40474_row2_col9, #T_40474_row2_col10, #T_40474_row2_col11 {
#   background-color: Light Grey;
#   color: Black;
#   border-color: white;
# }
# </style>
# <table id="T_40474">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40474_level0_col0" class="col_heading level0 col0" >LookupDomain</th>
#       <th id="T_40474_level0_col1" class="col_heading level0 col1" >FirstIndexed</th>
#       <th id="T_40474_level0_col2" class="col_heading level0 col2" >LastIndexed</th>
#       <th id="T_40474_level0_col3" class="col_heading level0 col3" >SalesRevenue</th>
#       <th id="T_40474_level0_col4" class="col_heading level0 col4" >SpendDate</th>
#       <th id="T_40474_level0_col5" class="col_heading level0 col5" >SpendSum</th>
#       <th id="T_40474_level0_col6" class="col_heading level0 col6" >CompanyName</th>
#       <th id="T_40474_level0_col7" class="col_heading level0 col7" >Vertical</th>
#       <th id="T_40474_level0_col8" class="col_heading level0 col8" >State</th>
#       <th id="T_40474_level0_col9" class="col_heading level0 col9" >Country</th>
#       <th id="T_40474_level0_col10" class="col_heading level0 col10" >ARank</th>
#       <th id="T_40474_level0_col11" class="col_heading level0 col11" >QRank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40474_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40474_row0_col0" class="data row0 col0" >businesslease.pl</td>
#       <td id="T_40474_row0_col1" class="data row0 col1" >2002-02-08 08:00:00</td>
#       <td id="T_40474_row0_col2" class="data row0 col2" >2023-07-15 07:00:00</td>
#       <td id="T_40474_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_40474_row0_col4" class="data row0 col4" >2002-06-18 18:47:00</td>
#       <td id="T_40474_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_40474_row0_col6" class="data row0 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_40474_row0_col7" class="data row0 col7" >Business And Industrial</td>
#       <td id="T_40474_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_40474_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_40474_row0_col10" class="data row0 col10" >15805159</td>
#       <td id="T_40474_row0_col11" class="data row0 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_40474_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40474_row1_col0" class="data row1 col0" >businesslease.pl</td>
#       <td id="T_40474_row1_col1" class="data row1 col1" >2002-02-08 08:00:00</td>
#       <td id="T_40474_row1_col2" class="data row1 col2" >2023-07-15 07:00:00</td>
#       <td id="T_40474_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_40474_row1_col4" class="data row1 col4" >2018-07-24 18:47:00</td>
#       <td id="T_40474_row1_col5" class="data row1 col5" >40</td>
#       <td id="T_40474_row1_col6" class="data row1 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_40474_row1_col7" class="data row1 col7" >Business And Industrial</td>
#       <td id="T_40474_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_40474_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_40474_row1_col10" class="data row1 col10" >15805159</td>
#       <td id="T_40474_row1_col11" class="data row1 col11" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_40474_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40474_row2_col0" class="data row2 col0" >businesslease.pl</td>
#       <td id="T_40474_row2_col1" class="data row2 col1" >2002-02-08 08:00:00</td>
#       <td id="T_40474_row2_col2" class="data row2 col2" >2023-07-15 07:00:00</td>
#       <td id="T_40474_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_40474_row2_col4" class="data row2 col4" >2020-05-14 18:47:00</td>
#       <td id="T_40474_row2_col5" class="data row2 col5" >507</td>
#       <td id="T_40474_row2_col6" class="data row2 col6" >Business Lease Poland Sp. z o.o.</td>
#       <td id="T_40474_row2_col7" class="data row2 col7" >Business And Industrial</td>
#       <td id="T_40474_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_40474_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_40474_row2_col10" class="data row2 col10" >15805159</td>
#       <td id="T_40474_row2_col11" class="data row2 col11" >-1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Filter insignificant technologies

# %%
# TODO

# %% [markdown]
# ## Risk: Decreased Spending

# %% [markdown]
# ### Add SpendChange colum

# %%
def add_spend_change(df):
    df = df.sort_values(by=['LookupDomain', 'SpendDate'])
    df['SpendChange'] = df.groupby('LookupDomain')['SpendSum'].pct_change()
    return df

def add_rolling_spend_change(df, window):
    df = df.sort_values(by=['LookupDomain', 'SpendDate'])
    df['RollingSpendChange'] = df.groupby('LookupDomain')['SpendSum'].pct_change(periods=window)
    return df

spend_data = add_spend_change(spend_data)

window = 2  # Specify the window size for the rolling calculation
spend_data = add_rolling_spend_change(spend_data, window)

view_table(spend_data,5)
# Out:
# <style type="text/css">
# #T_7de9a_row0_col0, #T_7de9a_row0_col1, #T_7de9a_row0_col2, #T_7de9a_row0_col3, #T_7de9a_row0_col4, #T_7de9a_row0_col5, #T_7de9a_row0_col6, #T_7de9a_row0_col7, #T_7de9a_row0_col8, #T_7de9a_row0_col9, #T_7de9a_row0_col10, #T_7de9a_row0_col11, #T_7de9a_row0_col12, #T_7de9a_row0_col13, #T_7de9a_row1_col0, #T_7de9a_row1_col1, #T_7de9a_row1_col2, #T_7de9a_row1_col3, #T_7de9a_row1_col4, #T_7de9a_row1_col5, #T_7de9a_row1_col6, #T_7de9a_row1_col7, #T_7de9a_row1_col8, #T_7de9a_row1_col9, #T_7de9a_row1_col10, #T_7de9a_row1_col11, #T_7de9a_row1_col12, #T_7de9a_row1_col13, #T_7de9a_row2_col0, #T_7de9a_row2_col1, #T_7de9a_row2_col2, #T_7de9a_row2_col3, #T_7de9a_row2_col4, #T_7de9a_row2_col5, #T_7de9a_row2_col6, #T_7de9a_row2_col7, #T_7de9a_row2_col8, #T_7de9a_row2_col9, #T_7de9a_row2_col10, #T_7de9a_row2_col11, #T_7de9a_row2_col12, #T_7de9a_row2_col13, #T_7de9a_row3_col0, #T_7de9a_row3_col1, #T_7de9a_row3_col2, #T_7de9a_row3_col3, #T_7de9a_row3_col4, #T_7de9a_row3_col5, #T_7de9a_row3_col6, #T_7de9a_row3_col7, #T_7de9a_row3_col8, #T_7de9a_row3_col9, #T_7de9a_row3_col10, #T_7de9a_row3_col11, #T_7de9a_row3_col12, #T_7de9a_row3_col13, #T_7de9a_row4_col0, #T_7de9a_row4_col1, #T_7de9a_row4_col2, #T_7de9a_row4_col3, #T_7de9a_row4_col4, #T_7de9a_row4_col5, #T_7de9a_row4_col6, #T_7de9a_row4_col7, #T_7de9a_row4_col8, #T_7de9a_row4_col9, #T_7de9a_row4_col10, #T_7de9a_row4_col11, #T_7de9a_row4_col12, #T_7de9a_row4_col13 {
#   background-color: Light Grey;
#   color: Black;
#   border-color: white;
# }
# </style>
# <table id="T_7de9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7de9a_level0_col0" class="col_heading level0 col0" >LookupDomain</th>
#       <th id="T_7de9a_level0_col1" class="col_heading level0 col1" >FirstIndexed</th>
#       <th id="T_7de9a_level0_col2" class="col_heading level0 col2" >LastIndexed</th>
#       <th id="T_7de9a_level0_col3" class="col_heading level0 col3" >SalesRevenue</th>
#       <th id="T_7de9a_level0_col4" class="col_heading level0 col4" >SpendDate</th>
#       <th id="T_7de9a_level0_col5" class="col_heading level0 col5" >SpendSum</th>
#       <th id="T_7de9a_level0_col6" class="col_heading level0 col6" >CompanyName</th>
#       <th id="T_7de9a_level0_col7" class="col_heading level0 col7" >Vertical</th>
#       <th id="T_7de9a_level0_col8" class="col_heading level0 col8" >State</th>
#       <th id="T_7de9a_level0_col9" class="col_heading level0 col9" >Country</th>
#       <th id="T_7de9a_level0_col10" class="col_heading level0 col10" >ARank</th>
#       <th id="T_7de9a_level0_col11" class="col_heading level0 col11" >QRank</th>
#       <th id="T_7de9a_level0_col12" class="col_heading level0 col12" >SpendChange</th>
#       <th id="T_7de9a_level0_col13" class="col_heading level0 col13" >RollingSpendChange</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7de9a_level0_row0" class="row_heading level0 row0" >68</th>
#       <td id="T_7de9a_row0_col0" class="data row0 col0" >al-umrah.com</td>
#       <td id="T_7de9a_row0_col1" class="data row0 col1" >2016-05-05 23:00:00</td>
#       <td id="T_7de9a_row0_col2" class="data row0 col2" >2022-10-02 07:00:00</td>
#       <td id="T_7de9a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7de9a_row0_col4" class="data row0 col4" >2016-06-13 23:08:00</td>
#       <td id="T_7de9a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7de9a_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_7de9a_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_7de9a_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_7de9a_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_7de9a_row0_col10" class="data row0 col10" >42277261</td>
#       <td id="T_7de9a_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_7de9a_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_7de9a_row0_col13" class="data row0 col13" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7de9a_level0_row1" class="row_heading level0 row1" >69</th>
#       <td id="T_7de9a_row1_col0" class="data row1 col0" >al-umrah.com</td>
#       <td id="T_7de9a_row1_col1" class="data row1 col1" >2016-05-05 23:00:00</td>
#       <td id="T_7de9a_row1_col2" class="data row1 col2" >2022-10-02 07:00:00</td>
#       <td id="T_7de9a_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_7de9a_row1_col4" class="data row1 col4" >2022-10-02 07:00:00</td>
#       <td id="T_7de9a_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_7de9a_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_7de9a_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_7de9a_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_7de9a_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_7de9a_row1_col10" class="data row1 col10" >42277261</td>
#       <td id="T_7de9a_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_7de9a_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_7de9a_row1_col13" class="data row1 col13" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7de9a_level0_row2" class="row_heading level0 row2" >94</th>
#       <td id="T_7de9a_row2_col0" class="data row2 col0" >aldautomotive.pl</td>
#       <td id="T_7de9a_row2_col1" class="data row2 col1" >2004-01-09 08:00:00</td>
#       <td id="T_7de9a_row2_col2" class="data row2 col2" >2023-07-16 07:00:00</td>
#       <td id="T_7de9a_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_7de9a_row2_col4" class="data row2 col4" >2004-05-07 03:11:00</td>
#       <td id="T_7de9a_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_7de9a_row2_col6" class="data row2 col6" >ALD Automotive Polska Sp. z o.o</td>
#       <td id="T_7de9a_row2_col7" class="data row2 col7" >Automotive And Vehicles</td>
#       <td id="T_7de9a_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_7de9a_row2_col9" class="data row2 col9" >PL</td>
#       <td id="T_7de9a_row2_col10" class="data row2 col10" >17482943</td>
#       <td id="T_7de9a_row2_col11" class="data row2 col11" >-1</td>
#       <td id="T_7de9a_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_7de9a_row2_col13" class="data row2 col13" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7de9a_level0_row3" class="row_heading level0 row3" >95</th>
#       <td id="T_7de9a_row3_col0" class="data row3 col0" >aldautomotive.pl</td>
#       <td id="T_7de9a_row3_col1" class="data row3 col1" >2004-01-09 08:00:00</td>
#       <td id="T_7de9a_row3_col2" class="data row3 col2" >2023-07-16 07:00:00</td>
#       <td id="T_7de9a_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_7de9a_row3_col4" class="data row3 col4" >2014-09-12 03:11:00</td>
#       <td id="T_7de9a_row3_col5" class="data row3 col5" >358</td>
#       <td id="T_7de9a_row3_col6" class="data row3 col6" >ALD Automotive Polska Sp. z o.o</td>
#       <td id="T_7de9a_row3_col7" class="data row3 col7" >Automotive And Vehicles</td>
#       <td id="T_7de9a_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_7de9a_row3_col9" class="data row3 col9" >PL</td>
#       <td id="T_7de9a_row3_col10" class="data row3 col10" >17482943</td>
#       <td id="T_7de9a_row3_col11" class="data row3 col11" >-1</td>
#       <td id="T_7de9a_row3_col12" class="data row3 col12" >inf</td>
#       <td id="T_7de9a_row3_col13" class="data row3 col13" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7de9a_level0_row4" class="row_heading level0 row4" >96</th>
#       <td id="T_7de9a_row4_col0" class="data row4 col0" >aldautomotive.pl</td>
#       <td id="T_7de9a_row4_col1" class="data row4 col1" >2004-01-09 08:00:00</td>
#       <td id="T_7de9a_row4_col2" class="data row4 col2" >2023-07-16 07:00:00</td>
#       <td id="T_7de9a_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_7de9a_row4_col4" class="data row4 col4" >2017-06-28 03:11:00</td>
#       <td id="T_7de9a_row4_col5" class="data row4 col5" >1525</td>
#       <td id="T_7de9a_row4_col6" class="data row4 col6" >ALD Automotive Polska Sp. z o.o</td>
#       <td id="T_7de9a_row4_col7" class="data row4 col7" >Automotive And Vehicles</td>
#       <td id="T_7de9a

# %% [markdown]
# ### Domains with Decreased Spend - Based on SpendChange

# %%
threshold = -0.25  # 25% decrease or more

decreased_spend_domains = spend_data.loc[spend_data['SpendChange'] <= threshold]['LookupDomain'].unique()

print(decreased_spend_domains)
# Out:
# ['carleasepolska.pl' 'destinology.co.uk' 'distantjourneys.co.uk'
#  'dreamworldtravel.co.uk' 'dwtltd.com' 'edreamtravels.co.uk' 'koin.com.br'
#  'travel-stop.co.uk']

# %% [markdown]
# #### Plot Decreased Spending

# %%
for domain in decreased_spend_domains:
    sd_for_domain = spend_data.loc[spend_data['LookupDomain'] == domain]
    print(sd_for_domain['SpendSum'].values)
    plot_count_over_time(sd_for_domain, 'Avg Monthly Spend($) for ' + domain, 'SpendDate', 'SpendSum', 'Monthly Spend $')
# Out:
# [  0 252 353 379 279 379]
# [   0  466  564  616 1036 2736 2921 2454 2511 1247  529  685  772  998
#  1812 1780 1897 1957 2180 2063 1951 1411 1444 1756 1854 2008 2268 2246
#   879 2375]
# [   0   31  553 1093 1146  606 1146]
# [ 21  75 172 151   0 151]
# [ 0 21  0]
# [80  0 80]
# [   0   37  200  231  253  335  314  836 1022 1409 1822 2055 2278 2258
#  2794 2847 2201 1639 1821 1906 1684 2131]
# [ 0 31 65 34 34]

# %% [markdown]
# ### Domains with Decreased Spend - Based on RollingSpendChange

# %%
threshold = -0.25  # 25% decrease or more

decreased_rolling_spend_domains = spend_data.loc[spend_data['RollingSpendChange'] <= threshold]['LookupDomain'].unique()

print(decreased_rolling_spend_domains)
# Out:
# ['destinology.co.uk' 'distantjourneys.co.uk' 'dreamworldtravel.co.uk'
#  'koin.com.br' 'travel-stop.co.uk']

# %% [markdown]
# #### Plot Decreased Spending

# %%
for domain in decreased_rolling_spend_domains:
    sd_for_domain = spend_data.loc[spend_data['LookupDomain'] == domain]
    print(sd_for_domain['SpendSum'].values)
    plot_count_over_time(sd_for_domain, 'Avg Monthly Spend($) for ' + domain, 'SpendDate', 'SpendSum', 'Monthly Spend $')
# Out:
# [   0  466  564  616 1036 2736 2921 2454 2511 1247  529  685  772  998
#  1812 1780 1897 1957 2180 2063 1951 1411 1444 1756 1854 2008 2268 2246
#   879 2375]
# [   0   31  553 1093 1146  606 1146]
# [ 21  75 172 151   0 151]
# [   0   37  200  231  253  335  314  836 1022 1409 1822 2055 2278 2258
#  2794 2847 2201 1639 1821 1906 1684 2131]
# [ 0 31 65 34 34]

# %% [markdown]
# #### View Tech Spend over time

# %%
domain = 'dreamworldtravel.co.uk'
sd_for_domain = spend_data.loc[spend_data['LookupDomain'] == 'dreamworldtravel.co.uk']

plot_count_over_time(sd_for_domain, 'Avg Monthly Spend $ for ' + domain, 'SpendDate', 'SpendSum', 'Monthly Spend $')

# %% [markdown]
# ## Technology Count Decrease

# %%
bw_tech_tags = [ 'ads', 'widgets', 'analytics', 'shop', 'feeds', 'javascript', 'cms', 'Web Master', 'seo_headers', 'framework', 'cdns', 'payment', 'parked', 'encoding', 'mobile', 'mapping', 'Server', 'mx', 'ssl', 'link', 'hosting', 'seo_title', 'CDN', 'seo_meta', 'ns', 'shipping', 'language', 'copyright', 'robots', 'registrar']
included_tech_tags = [ 'ads', 'widgets', 'analytics', 'shop', 'feeds', 'cms', 'seo_headers','cdns', 'payment', 'parked', 'encoding', 'mobile', 'mapping', 'Server', 'mx', 'ssl', 'link', 'hosting', 'seo_title', 'CDN', 'seo_meta', 'ns', 'shipping', 'language', 'copyright', 'robots', 'registrar']


### NOTE ###
# Exclude in category level instead of tag
############
# Out:
# ['ads', 'widgets', 'analytics', 'shop', 'feeds', 'cms', 'seo_headers', 'cdns', 'payment', 'parked', 'encoding', 'mobile', 'mapping', 'Server', 'mx', 'ssl', 'link', 'hosting', 'seo_title', 'CDN', 'seo_meta', 'ns', 'shipping', 'language', 'copyright', 'robots', 'registrar']

# %% [markdown]
# ### Create Monthly Live Tech Table

# %%
def create_monthly_live_tech_data(df):
   # Initialize an empty list to store rows for the new DataFrame
    new_rows = []

    # Iterate over each row in the original DataFrame
    for _, row in df.iterrows():
        startDate = row['FirstDetected'].replace(minute=0, hour=0, second=0)
        endDate = add_months_to_datetime(row['LastDetected'],1).replace(minute=0, hour=0, second=0)
        date_range = pd.date_range(startDate, endDate , freq='M')
        tech_activity = pd.DataFrame({
            'Domain': [row['Domain']] * len(date_range),
            'DubDomain': [row['Domain']] * len(date_range),
            'Url': [row['Url']] * len(date_range),
            'FirstIndexed': [row['FirstIndexed']] * len(date_range),
            'LastIndexed': [row['LastIndexed']] * len(date_range),
            'CompanyName': [row['CompanyName']] * len(date_range),
            'Vertical': [row['Vertical']] * len(date_range),
            'Country': [row['Country']] * len(date_range),
            'Name': [row['Name']] * len(date_range),
            'Parent': [row['Parent']] * len(date_range),
            'FirstDetected': [row['FirstDetected']] * len(date_range),
            'LastDetected': [row['LastDetected']] * len(date_range),
            'IsPremium': [row['IsPremium']] * len(date_range),
            'LiveMonth': date_range,
            'Tag': [row['Tag']] * len(date_range),
            'Category0': [row['Category0']] * len(date_range),
            'Category1': [row['Category1']] * len(date_range),
            'Category2': [row['Category2']] * len(date_range),
            'Category3': [row['Category3']] * len(date_range),
            'Category4': [row['Category4']] * len(date_range),
            'Category5': [row['Category5']] * len(date_range),
            'Category6': [row['Category6']] * len(date_range),
            'Category7': [row['Category7']] * len(date_range),
            'Category8': [row['Category8']] * len(date_range),
            'Category9': [row['Category9']] * len(date_range),
        })

        new_rows.append(tech_activity)

    # Concatenate all rows to create the new DataFrame
    new_df = pd.concat(new_rows, ignore_index=True)

    return new_df

# Monthly live tech data
monthly_active_tech_data = create_monthly_live_tech_data(tech_data)

# Mothly live tech data excluding redundant tech
tech_data_excluded_tags_data = tech_data[tech_data['Tag'].isin(excluded_tech_tags)] 
monthly_active_filtered_tech_data = create_monthly_live_tech_data(tech_data_excluded_tags_data)
view_table(monthly_active_tech_data,3)
# Out:
#   Cell In[884], line 49
#     tech_data_excluded_tags_data = tech_data[tech_data['Tag'] not isin(excluded_tech_tags)]
#                                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Calc Table: [Domain, LiveMonth, Premium_yes, Premium_no, Premium_maybe, Total ]

def create_premium_count_dataframe(df):
    # Pivot the DataFrame to create separate columns for each unique value in 'IsPremium' column
    pivoted_df = df.pivot_table(index=['Domain', 'LiveMonth'], columns='IsPremium', aggfunc='size', fill_value=0)

    # Reset the index and rename the columns
    pivoted_df = pivoted_df.reset_index().rename_axis(None, axis=1)

    # Rename the columns to include 'PremiumCount_' prefix
    pivoted_df.columns = ['Domain', 'LiveMonth'] + ['Premium_' + str(col) for col in pivoted_df.columns[2:]]
    
    pivoted_df['Total'] = pivoted_df['Premium_yes'] + pivoted_df['Premium_no'] + pivoted_df['Premium_maybe']

    return pivoted_df


premium_count_data = create_premium_count_dataframe(monthly_active_tech_data)

# %%
## TODO: Calc Rolling Change
## TODO: Remove insignificant technologies

def plot_active_monthly_tech_count_data(df, domain):
    df_domain = df.loc[df['Domain'] == domain]
    title = 'Technology Count for ' + domain
    df_domain.plot(title= title, x='LiveMonth', y=[ 'Total','Premium_yes', 'Premium_no'])

for domain in premium_count_data['Domain'].unique():
    plot_active_monthly_tech_count_data(premium_count_data, domain)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:509: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)

# %%
domain = 'al-umrah.com'
premium_count_for_domain = premium_count_data.loc[premium_count_data['Domain'] == domain]

view_table(premium_count_for_domain)
